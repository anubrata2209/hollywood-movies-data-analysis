# %%
 # advanced visualisation
import pandas as pd
import os

# %%
movies = pd.read_excel("100_hollywood_movies_sample_data.xlsx")
movies
# Out:
#                                      Movie Name     Genre  Budget (Million $)  \
# 0                                    Spider-Man     Crime                 195
# 1                               The Dark Knight   Fantasy                 141
# 2                                     Inception   Fantasy                 167
# 3                                        Avatar   Romance                 136
# 4                                       Titanic    Comedy                 132
# ..                                          ...       ...                 ...
# 95               Jurassic World: Fallen Kingdom  Thriller                 161
# 96                     Jurassic World: Dominion     Crime                  74
# 97                     Avatar: The Way of Water     Drama                 120
# 98                      Spider-Man: No Way Home    Action                 150
# 99  Doctor Strange in the Multiverse of Madness    Sci-Fi                  90
#
# ...

# %%
len(movies)
# Out:
# 100

# %%
movies.shape #(no. of rows and columns)
# Out:
# (100, 6)

# %%
movies.head() # head operation will give upto 5 rows
# Out:
#         Movie Name    Genre  Budget (Million $)  Audience Rating (%)  \
# 0       Spider-Man    Crime                 195                   60
# 1  The Dark Knight  Fantasy                 141                   72
# 2        Inception  Fantasy                 167                   73
# 3           Avatar  Romance                 136                   77
# 4          Titanic   Comedy                 132                   84
#
#    Rotten Tomatoes Rating (%)  Year of Release
# 0                          83             2009
# 1                          81             1999
# 2                          60             1998
# 3                          81             2018
# 4                          71             2018

# %%
movies. tail()
# Out:
#                                      Movie Name     Genre  Budget (Million $)  \
# 95               Jurassic World: Fallen Kingdom  Thriller                 161
# 96                     Jurassic World: Dominion     Crime                  74
# 97                     Avatar: The Way of Water     Drama                 120
# 98                      Spider-Man: No Way Home    Action                 150
# 99  Doctor Strange in the Multiverse of Madness    Sci-Fi                  90
#
#     Audience Rating (%)  Rotten Tomatoes Rating (%)  Year of Release
# 95                   62                          82             1996
# 96                   85                          72             2014
# 97                   80                           5             2007
# 98                   75                         115             2004
# 99                   85                         -10             2006

# %%
movies.columns
# Out:
# Index(['Movie Name', 'Genre', 'Budget (Million $)', 'Audience Rating (%)',
#        'Rotten Tomatoes Rating (%)', 'Year of Release'],
#       dtype='object')

# %%
movies.columns = ['Film' , 'Genre' ,'BudgetMillions','AudienceRating','CriticRating','Year']

# %%
movies.head() #removed space  and % remove noise characters
# Out:
#               Film    Genre  BudgetMillions  AudienceRating  CriticRating  \
# 0       Spider-Man    Crime             195              60            83
# 1  The Dark Knight  Fantasy             141              72            81
# 2        Inception  Fantasy             167              73            60
# 3           Avatar  Romance             136              77            81
# 4          Titanic   Comedy             132              84            71
#
#    Year
# 0  2009
# 1  1999
# 2  1998
# 3  2018
# 4  2018

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            100 non-null    object
#  1   Genre           100 non-null    object
#  2   BudgetMillions  100 non-null    int64
#  3   AudienceRating  100 non-null    int64
#  4   CriticRating    100 non-null    int64
#  5   Year            100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
movies.describe()
# if we look at the yr the data type is int but when we look at the mean value it is showing some year which is 
# we have to change to catagory type
# also from object datatype we will convert to catagory datatypes
# Out:
#        BudgetMillions  AudienceRating  CriticRating         Year
# count      100.000000      100.000000    100.000000   100.000000
# mean       126.870000       77.270000     70.110000  2006.940000
# std         42.402748       10.777694     14.371616    10.594281
# min         50.000000       60.000000    -10.000000  1990.000000
# 25%         92.500000       68.000000     63.750000  1997.750000
# 50%        124.000000       78.000000     71.500000  2006.500000
# 75%        164.250000       85.500000     79.000000  2017.250000
# max        200.000000       95.000000    115.000000  2025.000000

# %%
movies
# Out:
#                                            Film     Genre  BudgetMillions  \
# 0                                    Spider-Man     Crime             195
# 1                               The Dark Knight   Fantasy             141
# 2                                     Inception   Fantasy             167
# 3                                        Avatar   Romance             136
# 4                                       Titanic    Comedy             132
# ..                                          ...       ...             ...
# 95               Jurassic World: Fallen Kingdom  Thriller             161
# 96                     Jurassic World: Dominion     Crime              74
# 97                     Avatar: The Way of Water     Drama             120
# 98                      Spider-Man: No Way Home    Action             150
# 99  Doctor Strange in the Multiverse of Madness    Sci-Fi              90
#
#     AudienceRating  CriticRating  Year
# 0               60            83  2009
# ...

# %%
movies.head()
# Out:
#               Film    Genre  BudgetMillions  AudienceRating  CriticRating  \
# 0       Spider-Man    Crime             195              60            83
# 1  The Dark Knight  Fantasy             141              72            81
# 2        Inception  Fantasy             167              73            60
# 3           Avatar  Romance             136              77            81
# 4          Titanic   Comedy             132              84            71
#
#    Year
# 0  2009
# 1  1999
# 2  1998
# 3  2018
# 4  2018

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            100 non-null    object
#  1   Genre           100 non-null    object
#  2   BudgetMillions  100 non-null    int64
#  3   AudienceRating  100 non-null    int64
#  4   CriticRating    100 non-null    int64
#  5   Year            100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
movies['Film']
# Out:
# 0                                      Spider-Man
# 1                                 The Dark Knight
# 2                                       Inception
# 3                                          Avatar
# 4                                         Titanic
#                          ...
# 95                 Jurassic World: Fallen Kingdom
# 96                       Jurassic World: Dominion
# 97                       Avatar: The Way of Water
# 98                        Spider-Man: No Way Home
# 99    Doctor Strange in the Multiverse of Madness
# Name: Film, Length: 100, dtype: object

# %%
movies['Film'] = movies['Film'].astype('category')

# %%
movies.head()
# Out:
#               Film    Genre  BudgetMillions  AudienceRating  CriticRating  \
# 0       Spider-Man    Crime             195              60            83
# 1  The Dark Knight  Fantasy             141              72            81
# 2        Inception  Fantasy             167              73            60
# 3           Avatar  Romance             136              77            81
# 4          Titanic   Comedy             132              84            71
#
#    Year
# 0  2009
# 1  1999
# 2  1998
# 3  2018
# 4  2018

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            100 non-null    category
#  1   Genre           100 non-null    object
#  2   BudgetMillions  100 non-null    int64
#  3   AudienceRating  100 non-null    int64
#  4   CriticRating    100 non-null    int64
#  5   Year            100 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 9.0+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            100 non-null    category
#  1   Genre           100 non-null    category
#  2   BudgetMillions  100 non-null    int64
#  3   AudienceRating  100 non-null    int64
#  4   CriticRating    100 non-null    int64
#  5   Year            100 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 9.3 KB

# %%
movies.head()
# Out:
#               Film    Genre  BudgetMillions  AudienceRating  CriticRating  \
# 0       Spider-Man    Crime             195              60            83
# 1  The Dark Knight  Fantasy             141              72            81
# 2        Inception  Fantasy             167              73            60
# 3           Avatar  Romance             136              77            81
# 4          Titanic   Comedy             132              84            71
#
#    Year
# 0  2009
# 1  1999
# 2  1998
# 3  2018
# 4  2018

# %%
movies.Genre
# Out:
# 0        Crime
# 1      Fantasy
# 2      Fantasy
# 3      Romance
# 4       Comedy
#         ...
# 95    Thriller
# 96       Crime
# 97       Drama
# 98      Action
# 99      Sci-Fi
# Name: Genre, Length: 100, dtype: category
# Categories (10, object): ['Action', 'Adventure', 'Animation', 'Comedy', ..., 'Fantasy', 'Romance', 'Sci-Fi', 'Thriller']

# %%
movies.describe()
# Out:
#        BudgetMillions  AudienceRating  CriticRating
# count      100.000000      100.000000    100.000000
# mean       126.870000       77.270000     70.110000
# std         42.402748       10.777694     14.371616
# min         50.000000       60.000000    -10.000000
# 25%         92.500000       68.000000     63.750000
# 50%        124.000000       78.000000     71.500000
# 75%        164.250000       85.500000     79.000000
# max        200.000000       95.000000    115.000000

# %%
# how to work in joint plots
from matplotlib import pyplot as plt
import seaborn as sns 
# %matplotlib inline 
# all the plot should inside the line
    
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot( data = movies ,x = 'CriticRating' , y= 'AudienceRating')

# %%
j = sns.jointplot( data = movies ,x = 'CriticRating' , y= 'AudienceRating',kind = 'reg')

# %%
j = sns.jointplot( data = movies ,x = 'CriticRating' , y= 'AudienceRating',kind = 'hex')

# %%
#histograms

#<<< chart1
# distribution plot
m1 = sns.displot(movies.AudienceRating)

#y - axis generated by seaborn automatically that is the poweful of seaborn gallery

# %%
m1 = sns.displot(movies.CriticRating)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.displot(movies.AudienceRating, bins = 20) #in histogram won't get any lines but in distribution we get the lines

# %%
# sns.set_style('darkgrid')
n1 = plt.hist(movies.AudienceRating , bins = 15)

# %%
sns.set_style('white') #normal distribution and called as bell curve
n1 = plt.hist(movies.AudienceRating , bins = 20)

# %%
n1 = plt.hist(movies.CriticRating , bins = 20) #uniform distribution

# %%
# chart 2 
# creating stacked histogram

# %%
# h1 = plt.hist(movies.BudgetMillions)

plt.hist(movies.BudgetMillions)
plt.show()

# %%
vis1 = sns.lmplot(data = movies ,x ='CriticRating', y ='AudienceRating' , fit_reg = True) #lm=linear model

# %%
#vis1 = sns.lmplot(data = movies ,x ='CriticRating', y ='AudienceRating' , fit_reg = True ,hue = 'Genre',size= 5)
vis1 = sns.lmplot(
    data=movies,
    x='CriticRating',
    y='AudienceRating',
    fit_reg=True,
    hue='Genre',
    height=5
)

# %%
vis1 = sns.lmplot(data = movies ,x ='CriticRating', y ='AudienceRating' , fit_reg = False ,hue = 'Genre',height= 5)

# %%
vis1 = sns.regplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=True)

# %%
vis1 = sns.regplot(
    data=movies,
    x='CriticRating',
    y='AudienceRating',
    fit_reg=False
)

# %%
# kernel density estimate plot (KDE PLOT)
# HOW can we visualize audience rating and critics rating using scatterplot

# %%
#k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating)
k1 = sns.kdeplot(
    data=movies,
    x="CriticRating",
    y="AudienceRating"
)

# %%
#k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating ,shade =False , shade_lowest = True ,cmap= 'Reds' )
k1 = sns.kdeplot(
    data=movies,
    x="CriticRating",
    y="AudienceRating",
    fill=False,        # equivalent of shade=False
    cmap="Reds"
)

# %%
#k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating ,shade =True , shade_lowest = False ,cmap= 'Reds' )
sns.kdeplot(data=movies,
            x="CriticRating",
            y="AudienceRating",
            fill=True,
            cmap="Reds")
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
#k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating ,shade_lowest =True , cmap= 'Greens_r' )
k1 = sns.kdeplot(
    data=movies,
    x="CriticRating",
    y="AudienceRating",
    fill=True,
    cmap="Greens_r"
)

# %%
#k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRating ,shade_lowest =False , cmap= 'Greens_r' )
k1 = sns.kdeplot(
    data=movies,
    x="CriticRating",
    y="AudienceRating",
    fill=False,        # if you want shaded KDE
    cmap="Greens_r"
)

# %%
import seaborn as sns

sns.set_style('dark')

k1 = sns.kdeplot(
    x=movies["BudgetMillions"],
    y=movies["AudienceRating"],
    fill=True,
    cmap="Greens_r"
)

# %%
#sns.set_style('dark')
#k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)
sns.set_style('dark')

k1 = sns.kdeplot(
    data=movies,
    x="BudgetMillions",
    y="AudienceRating"
)

# %%
#k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)


k2 = sns.kdeplot(
    data=movies,
    x="BudgetMillions",
    y="CriticRating"
)

# %%
#sns.set_style('dark')
#k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)
sns.set_style('dark')

k1 = sns.kdeplot(
    data=movies,
    x="BudgetMillions",
    y="CriticRating"
)

# %%
# subplots

f, ax = plt.subplots(1,2,figsize = (10,5)) #figsize = height and wedth , here 1 is row  and 2 is for column

# %%
#f, axes = plt.subplots(1,2 , figsize = (10,5)) #figsize = height and wedth , here 1 is row  and 2 is for column

#k1= sns.kdeplot(movies.BudgetMillions,movies.AudienceRating ,ax = axes[0])
#k2= sns.kdeplot(movies.BudgetMillions,movies.CriticRating ,ax = axes[1])
f, axes = plt.subplots(1, 2, figsize=(10, 5))  # 1 row, 2 columns

k1 = sns.kdeplot(
    data=movies,
    x="BudgetMillions",
    y="AudienceRating",
    ax=axes[0]
)

k2 = sns.kdeplot(
    data=movies,
    x="BudgetMillions",
    y="CriticRating",
    ax=axes[1]
)

# %%
# Boxplots -

w = sns.boxplot(data= movies , x='Genre' , y= 'CriticRating')

# %%
# violin plot

z= sns.violinplot(data = movies ,x ='Genre' , y= 'CriticRating')

# %%
w1 = sns.boxplot(data = movies[movies.Genre== 'Action'] ,x= 'Year',y = 'AudienceRating')

# %%
plt.figure(figsize=(10, 7))

w1 = sns.boxplot(
    data=movies[movies.Genre == 'Action'],
    x='Year',
    y='AudienceRating'
)

plt.xticks(rotation=45)
plt.title("Audience Rating Distribution for Action Movies by Year")
plt.show()

# %%
# creating a facet grid

# %%
print(movies.shape)
print(movies.columns)
print(movies.head())
# Out:
# (100, 6)
# Index(['Film', 'Genre', 'BudgetMillions', 'AudienceRating', 'CriticRating',
#        'Year'],
#       dtype='object')
#               Film    Genre  BudgetMillions  AudienceRating  CriticRating  \
# 0       Spider-Man    Crime             195              60            83
# 1  The Dark Knight  Fantasy             141              72            81
# 2        Inception  Fantasy             167              73            60
# 3           Avatar  Romance             136              77            81
# 4          Titanic   Comedy             132              84            71
#
#    Year
# 0  2009
# 1  1999
# 2  1998
# 3  2018
# 4  2018

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(movies, col="Genre")
g.map_dataframe(sns.scatterplot, x="BudgetMillions", y="AudienceRating")

plt.show()

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
 #scatterplots are mapped  in facetgrid
g = sns.FacetGrid(movies, col='Genre', col_wrap=4)
g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
g = sns.FacetGrid(movies,row = 'Genre',col ='Year',hue ='Genre')
g = g.map(plt.hist,'BudgetMillions') # histogram are mapped in facetgrid

# %%
g = sns.FacetGrid(movies, col='Genre', col_wrap=4)
g.map(plt.hist, 'BudgetMillions')

import matplotlib.pyplot as plt
plt.show()

# %%
vis1 = sns.scatterplot(
    data=movies,
    x='CriticRating',
    y='AudienceRating',
    hue='Genre',
    s=10
)

# %%
vis1 = sns.scatterplot(
    data=movies,
    x='CriticRating',
    y='AudienceRating',
    hue='Genre'
)
